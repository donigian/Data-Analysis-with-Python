# %% [markdown]
# # Matplotlib is a visualization library
#
# - [Matplotlib](http://matplotlib.sourceforge.net)
# - [Matplotlib Gallery](http://matplotlib.sourceforge.net/gallery.html)
# - [Matplotlib Examples](http://matplotlib.sourceforge.net/examples)

# %%
# Cut & paste code from gallery and press CTRL-ENTER

# %%
# Cut & paste code from an example and press CTRL-ENTER

# %%
cd /Users/Babalu/Documents/data_analysis/data
# Out:
# /Users/Babalu/Documents/data_analysis/data

# %%
import pandas as pd 
# input file reference http://pandas.pydata.org/pandas-docs/dev/io.html
rusers = pd.read_csv('rusers.csv')

# %%
rusers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6984 entries, 0 to 6983
# Data columns (total 13 columns):
# Id                6984  non-null values
# Reputation        6984  non-null values
# CreationDate      6984  non-null values
# DisplayName       6984  non-null values
# LastAccessDate    6984  non-null values
# WebsiteUrl        1141  non-null values
# Location          1727  non-null values
# AboutMe           1305  non-null values
# Views             6984  non-null values
# UpVotes           6984  non-null values
# DownVotes         6984  non-null values
# EmailHash         6983  non-null values
# Age               1093  non-null values
# dtypes: float64(1), int64(5), object(7)

# %%
print rusers.UpVotes
# Out:
# 0      869
# 1       29
# 2     1851
# 3     1782
# 4      624
# 5     2874
# 6      225
# 7      994
# 8      378
# 9     3201
# 10     211
# 11    3076
# 12    2002
# 13     921
# 14    1806
# ...
# 6969    0
# 6970    0
# 6971    0
# 6972    0
# 6973    0
# 6974    0
# 6975    0
# 6976    0
# 6977    0
# 6978    0
# 6979    0
# 6980    0
# 6981    0
# 6982    0
# 6983    0
# Name: UpVotes, Length: 6984, dtype: int64

# %%
from pylab import *

X = rusers.UpVotes
Y = rusers.DownVotes

scatter(X,Y)
show()

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=cm.hot)
ax.set_zlim(-2,2)

# savefig('../figures/plot3d_ex.png',dpi=48)
show()

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=cm.hot)
ax.set_zlim(-2,2)

# savefig('../figures/plot3d_ex.png',dpi=48)
show()

# %%
from pylab import *

fig =figure()
fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)

subplot(2,1,1)
xticks([]), yticks([])

subplot(2,3,4)
xticks([]), yticks([])

subplot(2,3,5)
xticks([]), yticks([])

subplot(2,3,6)
xticks([]), yticks([])

show()

# %%
from pylab import *

ax = axes([0.025,0.025,0.95,0.95], polar=True)

N = 20
theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor( cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
# savefig('../figures/polar_ex.png',dpi=48)
show()

# %%
from pylab import *

def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

axes([0.025,0.025,0.95,0.95])

contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=cm.hot)
C = contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
clabel(C, inline=1, fontsize=10)

xticks([]), yticks([])
# savefig('../figures/contour_ex.png',dpi=48)
show()
